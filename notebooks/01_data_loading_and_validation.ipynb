# %%
import pandas as pd

inputs = pd.read_csv("../data/raw/inputs_prices.csv", sep=";")
commodities = pd.read_csv("../data/raw/commodities_prices.csv", sep=";")
fx = pd.read_csv("../data/raw/exchange_rate.csv", sep=";")

# %%
inputs.head(), commodities.head(), fx.head()
# Out:
# (  currency        date   price  id_articulo
#  0      USD  2019-07-04  181.42        54609
#  1      USD  2020-03-30  168.13        54609
#  2      USD  2020-09-07  176.09        54609
#  3      USD  2020-09-21  187.31        54609
#  4      USD  2021-07-20  188.70        54609,
#           date commodity_id currency  price
#  0  2020-01-02        wheat      ARS  10450
#  1  2020-01-02         corn      ARS   8350
#  2  2020-01-02    sunflower      ARS  13750
#  3  2020-01-02     soybeans      ARS  15500
#  4  2020-01-02      sorghum      ARS   7750,
#           date  usd_ars_sell
#  0  1899-12-31          8.41
#  1  2014-10-31          8.50
#  2  2014-11-03          8.50
#  3  2014-11-04          8.51
#  4  2014-11-05          8.51)

# %%
inputs.info()
commodities.info()
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1141 entries, 0 to 1140
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   currency     1141 non-null   object
#  1   date         1141 non-null   object
#  2   price        1141 non-null   float64
#  3   id_articulo  1141 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 35.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6841 entries, 0 to 6840
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          6841 non-null   object
#  1   commodity_id  6841 non-null   object
#  2   currency      6841 non-null   object
#  3   price         6841 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 213.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2660 entries, 0 to 2659
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2660 non-null   object
#  1   usd_ars_sell  2660 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 41.7+ KB

# %%
inputs["date"] = pd.to_datetime(inputs["date"])
commodities["date"] = pd.to_datetime(commodities["date"])
fx["date"] = pd.to_datetime(fx["date"])

# %%
inputs.info()
commodities.info()
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1141 entries, 0 to 1140
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   currency     1141 non-null   object
#  1   date         1141 non-null   datetime64[ns]
#  2   price        1141 non-null   float64
#  3   id_articulo  1141 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 35.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6841 entries, 0 to 6840
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          6841 non-null   datetime64[ns]
#  1   commodity_id  6841 non-null   object
#  2   currency      6841 non-null   object
#  3   price         6841 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 213.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2660 entries, 0 to 2659
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2660 non-null   datetime64[ns]
#  1   usd_ars_sell  2660 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 41.7 KB
